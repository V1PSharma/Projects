# %%
import time
from IPython.display import clear_output
import numpy as np


## Initial Masti
while(1):
    clear_output()
    print("Wada-kam : Wada-kam")
    print("\n\nWhat would you like to play??")
    print('press   A    Tic-tek-toh'"\n""\t"'B    K.B.C.')
    
    while(1):
        #print('\n')
        var = input("A or B")
        if(var.upper() in ['A','B']): break
    
    if var.lower() =='b': 
        clear_output()
        print('Ah...')
        time.sleep(1)
        print('Checking...')
        time.sleep(2.5)
        clear_output()
        print("Big B Not available")
        time.sleep(1.1)
        print("\n\nPress   A   for   tic-tek-to \n\t0   for   main menu")
        
        while(1):
            var = input("A or 0")
            if(var.upper() in ['A','0','O']): break
        
        if var.lower()=='a':
            break
        elif var in ['0','O','o']: 
            continue

    elif var.lower() =='a': 
        break

time.sleep(1)
clear_output()
print("Hey, Let's play tic-tek-toh")
time.sleep(2)

# User Names
time.sleep(2)
p1 = input("User1 Choose a name:   ").capitalize()
clear_output()
time.sleep(1)
while(1):
    p2 = input("User2 Choose a different name:   ").capitalize()
    if(p2 != p1): break	


clear_output()


# Toss

def toss():
    result = np.random.randint(0,2)
    if(result==0): 
        result = "Heads"
        player = p1
    else: 
        result = "Tails"
        player = p2
    return result,player

print("Initial Toss")
print(f"      Heads: {p1} Calls")
print(f"      Tails: {p2} Calls")

time.sleep(1)


print("Initializing Toss....")
time.sleep(1)
'''clear_output()
print("Initializing Toss......")'''
time.sleep(2)
result,player1 = toss()
clear_output()
print("Toss:")
time.sleep(3)
clear_output()
print(f"Toss:  {result}")
print(f"{player1} you won")

time.sleep(4.5)
#player_call=''
while(1):
    clear_output()
    player_call = input(f"{player1}\n Call Head or Tails for 2nd Toss:\n  H:Head,T:Tails\n")
    if(player_call.lower() in ['h', 't' ,'head','heads','tails','tail']):
        break


x = [p1,p2]
x.remove(player1)
dusra = x[0]

if player_call.lower() in ['h','heads','head']:
    player_call4 = "Heads"
elif player_call.lower() in ['t','tails','tail']:
    player_call4 = "Tails"


#Second Toss
clear_output()
print("Initilising 2nd Toss.....")
print(f"{player1} called {player_call4}")
time.sleep(2.5)
clear_output()
h_or_t,garbage = toss()

if(h_or_t[0]==player_call.upper()):
    print(f"Toss: {h_or_t}")
    print(f"Yay!! {player1} Won the Toss")
    time.sleep(3.5)
    
    n=0
    while(n not in ['1','2']):
        clear_output()
        n = input(f"{player1}\nChoose between Sign Selection(0 or X) and First Chance\n\nEnter\n\t1 for    Sign Selection('0 or X') \n\t2 for   First Chance\n")
    
    m=0
    while(m not in ['0','X','O','o','x']):
        if (n=='1'):
            First_chance = dusra
            second_bajji = player1
            clear_output()
            m = input(f"\n{player1}\nChoose your sign\nEnter\n\tO or X\n")
            d = {player1:m.upper()}
        elif(n=='2'):
            First_chance = player1
            second_bajji = dusra
            clear_output()
            m = input(f"\n{dusra}\nChoose your sign\nEnter\n\t0 or X\n")
            d = {dusra:m.upper()}
                
    
                
else: 
    print(f"Toss: {h_or_t}")
    print(f"{dusra} won !!")
    time.sleep(3.5)
    n=0
    while(n not in ['1','2']):
        clear_output()
        n = input(f"{dusra}\nChoose between Sign Selection(0 or X) and First Chance\n\nEnter\n\t1 for    Sign Selection('0 or X') \n\t2 for    First Chance\n")
        
    m=0
    while(m not in ['0','X','O','x','o']):
        if (n=='1'):
            First_chance = player1
            second_bajji = dusra
            clear_output()
            m = input(f"{dusra}\nChoose your sign\nEnter\n\tO or X\n")
            d = {dusra:m.upper()}
        elif(n=='2'):
            First_chance = dusra
            second_bajji = player1
            clear_output()
            m = input(f"{player1}\nChoose your sign\nEnter\n\t0 or X\n")
            d = {player1:m.upper()}

            
            
k =[p1,p2]
k.remove(list(d.keys())[0])
if(list(d.values())[0]=='X'):
    e = {k[0]:'0'}
else:
    e = {k[0]:'X'}
    
d.update(e)
final_signs = d


#Final Status

time.sleep(1)
clear_output()
print(f"First Chance: {First_chance}:      {final_signs[First_chance]}")
print(f"Second Bajji: {second_bajji}:      {final_signs[second_bajji]}")
time.sleep(6)    
    
# Format/Printing
clear_output()
print("Format for input:  ")
print("\nInput: row space columns")
print("E.g. \n\t2 3 :-   2nd row and 3rd col\n\n")

#########
#########
#Here move from user input: Press any key




s = [['','',''],['','','X'],['','','']]
def display(s):
    print('Row1\t{0:^8} | {1:^8} | {2:^8}'.format('Col1','Col2','Col3'))
    print(f'\t{s[0][0]:^8} | {s[0][1]:^8} | {s[0][2]:^8}')
    print(f"\t{'':^8} | {'':^8} | {'':^8}")
    print('\t{:=^30}'.format(''))
    #2nd Row
    print(f"Row2\t{'':^8} | {'':^8} | {'':^8}")

    print(f'\t{s[1][0]:^8} | {s[1][1]:^8} | {s[1][2]:^8}')
    print(f"\t{'':^8} | {'':^8} | {'':^8}")

    print(f"\t{'':=^30}")
    #3rd Row
    print(f"Row3\t{'':^8} | {'':^8} | {'':^8}")

    print(f'\t{s[2][0]:^8} | {s[2][1]:^8} | {s[2][2]:^8}')
    print(f"\t{'':^8} | {'':^8} | {'':^8}")

display(s)    
time.sleep(9)
clear_output()
clear_output()
print(f"First Chance: {First_chance}")#:      {final_signs[First_chance]}")
print(f"Second Bajji: {second_bajji}")#:      {final_signs[second_bajji]}")
time.sleep(3) 
    
# Checker Functions...
def row_check(s):
    count = 0
    for i in range(3):
        count = 0
        for j in range(0,3):
            #print('i=',i,'  j=',j,'   s[j][i]=',s[i][j],'    s[i][0]= ',s[i][0])
            
            if ((s[i][j] == s[i][0]) and s[i][0] != ''):
                count+=1;
                #print(s[i][j],count)
        if count==3: return True,s[i][0]
    return False,s[i][0]
def col_check(s):
    for i in range(3):
        count = 0    
        for j in range(0,3):
            #print('i=',i,'  j=',j,'   s[j][i]=',s[j][i],'    s[i][0]= ',s[i][0])
            if ((s[j][i] == s[0][i]) and (s[0][i] != '')):
                    #print(s[j][i],count,end = '.')

                count+=1;
                #print(s[j][i],count)
        if count==3: return True,s[0][i]
        #print('\n')
    return False,s[0][i]
def diag_check(s):
    
    #First Diag.
    count=0
    for i in range(3):
        if(s[i][i]==s[0][0] and s[0][0] != ''):
            count += 1
    if count==3: return True,s[0][0]  
    
    #Second Diag.
    count=0
    for i in range(3):
        if(s[i][2-i]==s[0][2] and s[0][2] != ''):
            count += 1
    if count==3: return True,s[0][2]
    
    return False,s[0][2]
def all_enteires_full(s):
    for i in range(3):
        for j in range(3):
            if s[i][j] in ['',' ']: return False
    return True


#Game 
    #User Input
def take_input(input_history,anything):
    ls=[]
    #Not in input_history
    #print(input_history)
    if anything%2 ==0:
        ls = input(f"{First_chance} choose a pos").split()
    else:
        ls = input(f"{second_bajji} choose a pos").split()

        
    while(1):
        lenls=len(ls)
        ls = tuple(ls)
        #print(ls)
        count=0
        if(ls not in input_history and lenls==2):
            
            for i in range(len(ls)):
                if(ls[i].isnumeric()): 
                    if(int(ls[i]) in [1,2,3]):
                        count +=1
            
        if (count==len(ls) and len(ls)==2):
            #print(lenls)
            break
        else:
            if(anything%2==0):
                ls = input(f"{First_chance} choose a pos").split()
            else:
                ls = input(f"{second_bajji} choose a pos").split()    
    n,m = ls
    
    return n,m

## Final GAme

clear_output()
print('Finally Game Begins!!')
time.sleep(2)
clear_output()
s = [['','',''],['','',''],['','','']]
input_history=[]
t = 9
anything=0
n1=''
m1=''
while(t):
    display(s)
    n1,m1 = take_input(input_history,anything)
    input_history.append((n1,m1))

    #Uploading to Matrix
    if (anything%2==0):        
        t-=1
        s[int(n1)-1][int(m1)-1] = final_signs[First_chance]
    elif(anything%2==1 ):
        t-=1
        s[int(n1)-1][int(m1)-1] = final_signs[second_bajji]
    
    
    #input_history.append((n,m))

    
    clear_output()
    anything+=1
    
    # Final Break
    if (t<=4):
        if(row_check(s)[0] or col_check(s)[0] or diag_check(s)[0] or (all_enteires_full(s))):
            break
clear_output()
        
s1,l1 = row_check(s)
s2,l2 = col_check(s)
s3,l3 = diag_check(s)

if s1:
    l=l1
    #print(1)
if s2==True:
    l=l2
    #print(2)
if s3:
    l=l3
    #print(3)
winner = list(final_signs.keys())[list(final_signs.values()).index(l)]

display(s)


if all_enteires_full(s): 
    print("\n\nAhh\n It's a Draw!!")
else:
    print(f"\n\nGame Over, {winner} won!!")
# Out:
# Row1	  Col1   |   Col2   |   Col3
# 	   0     |          |    X
# 	         |          |
# ...
# Row2	         |          |
# 	         |    0     |    X
# 	         |          |
# ...
# Row3	         |          |
# 	   0     |          |    X
# 	         |          |
#
#
# Game Over, L won!!
