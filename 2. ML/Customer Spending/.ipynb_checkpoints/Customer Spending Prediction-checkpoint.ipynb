# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Customer_Spending_Dataset/customer_data.csv')

# %%
df
# Out:
#                    name  age  gender    education  income
# 0    Teresa Williams MD   42  Female  High School   53936  \
# 1       Christine Myers   49  Female       Master   82468
# 2         Dwayne Moreno   55    Male     Bachelor   56941
# 3            Amy Norton   24  Female     Bachelor   60651
# 4           Tonya Adams   64    Male       Master   81884
# ..                  ...  ...     ...          ...     ...
# 995          Jason Haas   42  Female          PhD   98170
# 996       Sharon Valdez   39    Male  High School   59174
# 997       Andrew Taylor   50    Male       Master   59808
# 998     Jessica Johnson   50  Female       Master   58272
# 999      Brian Williams   38  Female     Bachelor   32512
#
#                     country  purchase_frequency   spending
# 0                  Slovenia                 0.9  13227.120
# 1                     Aruba                 0.6  12674.040
# 2                    Cyprus                 0.3   5354.115
# ...

# %%
df.isnull().sum()
# Out:
# name                  0
# age                   0
# gender                0
# education             0
# income                0
# country               0
# purchase_frequency    0
# spending              0
# dtype: int64

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=df['age'],y=df['spending'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x=df['age'],y=df['spending'])
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=df['gender'],y=df['spending'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(y=df['purchase_frequency'],x=df['income'],hue=df['spending'])
plt.legend(loc='upper left',bbox_to_anchor=(1.05,1),title='Total Spending')
plt.show()

# %% [markdown]
# # Data Setup

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
X = pd.get_dummies(df.drop(['spending','name'],axis=1))
y = df['spending']

# %%
poly = PolynomialFeatures(degree=2)

# %%
scaled_X = poly.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Training & Selection

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
elastic = ElasticNet()

# %%
elastic.fit(X_train,y_train)
# Out:
# /home/vip/Softwares/envs/dl/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.938e+08, tolerance: 2.400e+06
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet()

# %%
yred = elastic.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae = mean_absolute_error(y_test,yred)
rmse = mean_squared_error(y_test,yred)**0.5
#Percentage of Errors wrt y_test
mae/y_test.mean(),rmse/y_test.mean()
# Out:
# (0.1299091342342719, 0.17252480829426142)

# %%
param = {
        'l1_ratio':[0,0.5,0.75,1],
        'tol':[0.0001,0.001,0.00001],
        'random_state':[42],
}

# %%
grid = GridSearchCV(estimator=elastic,param_grid=param)

# %%
grid.fit(X_train,y_train)
# Out:
# /home/vip/Softwares/envs/dl/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.420e+08, tolerance: 1.955e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
ypred_grid = grid.predict(X_test)

# %%
mae1 = mean_absolute_error(y_test,ypred_grid)
rmse1 = mean_squared_error(y_test,ypred_grid)**0.5
mae1/y_test.mean(),rmse1/y_test.mean()
# Out:
# (0.061838558564609465, 0.08875869712079046)

# %%
import joblib

# %%
joblib.dump(grid,'Model.pkl')
# Out:
# ['Model.pkl']

# %%
grid.best_params_
# Out:
# {'l1_ratio': 1, 'random_state': 42, 'tol': 0.0001}
