# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Stroke Prediction Dataset/healthcare-dataset-stroke-data.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married
# 0      9046    Male  67.0             0              1          Yes  \
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status
# ...

# %% [markdown]
# # EDA

# %%
df = df.set_index('id')

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# #### Percentage of Null Entries

# %%
(df['bmi'].isnull().sum()/len(df))*100
# Out:
# 3.9334637964774952

# %% [markdown]
# #### Dropping 3.9% Rows: Since it can be a vital parameter and couldn't be computed from other parameters

# %%
df = df.drop( df[df['bmi'].isnull()].index,axis=0)

# %%
df.describe().transpose()
# Out:
#                     count        mean        std    min    25%    50%     75%
# age                4909.0   42.865374  22.555115   0.08  25.00  44.00   60.00  \
# hypertension       4909.0    0.091872   0.288875   0.00   0.00   0.00    0.00
# heart_disease      4909.0    0.049501   0.216934   0.00   0.00   0.00    0.00
# avg_glucose_level  4909.0  105.305150  44.424341  55.12  77.07  91.68  113.57
# bmi                4909.0   28.893237   7.854067  10.30  23.50  28.10   33.10
# stroke             4909.0    0.042575   0.201917   0.00   0.00   0.00    0.00
#
#                       max
# age                 82.00
# hypertension         1.00
# heart_disease        1.00
# avg_glucose_level  271.74
# bmi                 97.60
# stroke               1.00

# %% [markdown]
# # Visualization

# %%
sns.FacetGrid(col=)

# %%
sns.kdeplot(x=df['age'],y = df['heart_disease'],hue = df['stroke'])
plt.show()

# %%
sns.countplot(x=df['smoking_status'],hue=df['stroke'])
plt.show()

# %%
sns.countplot(x=df['heart_disease'],hue=df['stroke'])
plt.show()

# %% [markdown]
# # Effect of
#
# ### 1) Smoking Status:
#
#     a) 4.75% Chances of getting stroke if never smoked
#
#     b) 6.50% Chances of ever smoked

# %%
df[(df['smoking_status'] =='never smoked')]['stroke'].value_counts()
# Out:
# stroke
# 0    1768
# 1      84
# Name: count, dtype: int64

# %%
8400/1768
# Out:
# 4.751131221719457

# %%
df[(df['smoking_status'] =='smokes') | (df['smoking_status'] =='formerly smoked')]['stroke'].value_counts()
# Out:
# stroke
# 0    1478
# 1      96
# Name: count, dtype: int64

# %%
9600/1478
# Out:
# 6.495263870094723

# %% [markdown]
# ### 2) Hypertension
#
#
#     a) 3.45% Chance if not hypertension
#
#     b) 15.34% Chance if hypertension

# %%
df[df['hypertension']==0]['stroke'].value_counts()
# Out:
# stroke
# 0    4309
# 1     149
# Name: count, dtype: int64

# %%
14900/4309
# Out:
# 3.4578788582037596

# %%
df[df['hypertension']==1]['stroke'].value_counts()
# Out:
# stroke
# 0    391
# 1     60
# Name: count, dtype: int64

# %%
6000/391
# Out:
# 15.345268542199488

# %% [markdown]
# ### 3) Heart Disease
#
#     a) 3.76% Chances if no Heart Disease
#
#     b) 19.7% Chances if Patient has Heart Disease

# %%
df[df['heart_disease']==0]['stroke'].value_counts()
# Out:
# stroke
# 0    4497
# 1     169
# Name: count, dtype: int64

# %%
16900/4497
# Out:
# 3.758060929508561

# %%
df[df['heart_disease']==1]['stroke'].value_counts()
# Out:
# stroke
# 0    203
# 1     40
# Name: count, dtype: int64

# %%
4000/203
# Out:
# 19.704433497536947

# %% [markdown]
# ### 4) Age
#
#     a) 4.45% Chances if Age<60
#
#     b) 13.22% Chances if Age>=60

# %%
df[df['age']>=60]['stroke'].value_counts()
# Out:
# stroke
# 0    1135
# 1     150
# Name: count, dtype: int64

# %%
15000/1135
# Out:
# 13.215859030837004

# %%
df[df['hypertension']<=60]['stroke'].value_counts()
# Out:
# stroke
# 0    4700
# 1     209
# Name: count, dtype: int64

# %%
20900/4700
# Out:
# 4.446808510638298

# %% [markdown]
# ### 5) BMI
#
#     a) 2.42% Chances if BMI<=25
#
#     b) 5.46% Chances if BMI>25

# %%
df[df['bmi']>25]['stroke'].value_counts()
# Out:
# stroke
# 0    3131
# 1     171
# Name: count, dtype: int64

# %%
17100/3131
# Out:
# 5.461513893324816

# %%
df[df['bmi']<=25]['stroke'].value_counts()
# Out:
# stroke
# 0    1569
# 1      38
# Name: count, dtype: int64

# %%
3800/1569
# Out:
# 2.421924792861695

# %% [markdown]
# ### 6) Average Glucose Level
#
#     a) 3.21% Chances if Average Glucose Level<=120
#
#     b) 9.23% Chances if Average Glucose Level>120

# %%
df[df['avg_glucose_level']>120]['stroke'].value_counts()
# Out:
# stroke
# 0    964
# 1     89
# Name: count, dtype: int64

# %%
8900/964
# Out:
# 9.232365145228215

# %%
df[df['avg_glucose_level']<=120]['stroke'].value_counts()
# Out:
# stroke
# 0    3736
# 1     120
# Name: count, dtype: int64

# %%
12000/3736
# Out:
# 3.2119914346895073

# %%
df[['hypertension','heart_disease','avg_glucose_level','bmi','stroke']].corr()['stroke']
# Out:
# hypertension         0.142515
# heart_disease        0.137938
# avg_glucose_level    0.138936
# bmi                  0.042374
# stroke               1.000000
# Name: stroke, dtype: float64

# %%
sns.pairplot(df,hue='stroke')

# %% [markdown]
# # Data Setup

# %%
dumm = pd.get_dummies(df)

# %%
X = dumm.drop('stroke',axis=1)
y = dumm['stroke']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## AdaBoost Classifier

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {
    'n_estimators':[50,20,100],
    'learning_rate':[1.0,10,0.5],
    'algorithm':['SAMME.R','SAMME']
}

# %%
grid_ada = GridSearchCV(estimator=ada,param_grid=param)

# %%
grid_ada.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'algorithm': ['SAMME.R', 'SAMME'],
#                          'learning_rate': [1.0, 10, 0.5],
#                          'n_estimators': [50, 20, 100]})

# %%
grid_ada.best_estimator_
# Out:
# AdaBoostClassifier(learning_rate=10, random_state=42)

# %%
grid_ada.best_params_
# Out:
# {'algorithm': 'SAMME.R', 'learning_rate': 10, 'n_estimators': 50}

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
ypred_ada = grid_ada.predict(X_test)

# %% [markdown]
# # Results

# %%
print(classification_report(y_test,ypred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1401
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.95      1473
#    macro avg       0.48      0.50      0.49      1473
# weighted avg       0.90      0.95      0.93      1473

# %%
print(f"Accuracy: {round(accuracy_score(y_test,ypred_ada)*100,2)}%")
# Out:
# Accuracy: 95.11%

# %% [markdown]
# # Model Analysis

# %%
f_imp = pd.DataFrame(index=X.columns,data=grid_ada.best_estimator_.feature_importances_,columns=['Feature Importances'])

# %%
f_imp = f_imp.sort_values("Feature Importances")

# %%
f_imp =f_imp[f_imp['Feature Importances']>0]

# %%
sns.barplot(x=f_imp.index,y=f_imp['Feature Importances'])
plt.title('Feature Importances')
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Model Dump

# %%
import joblib

# %%
joblib.dump(grid_ada,'Adaptive Boosting.pkl')
# Out:
# ['Adaptive Boosting.pkl']
